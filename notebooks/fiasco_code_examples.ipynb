# %% [markdown]
# # fiasco Code Examples

# %%
from IPython.display import HTML
import numpy as np
import astropy.units as u
import fiasco
import matplotlib.pyplot as plt

# %matplotlib inline
# Out:
# /Users/willbarnes/anaconda/envs/fiasco/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
p = fiasco.io.Parser('fe_14.elvlc')

# %%
t = p.parse()

# %%
print(t)
# Out:
# level  config  label multiplicity L_label  J   E_obs       E_th
#                                                1 / cm     1 / cm
# ----- -------- ----- ------------ ------- --- -------- -----------
#     1   3s2.3p                  2       P 0.5      0.0         0.0
#     2   3s2.3p                  2       P 1.5  18852.0     18332.0
#     3   3s.3p2                  4       P 0.5 225114.0    221637.0
#     4   3s.3p2                  4       P 1.5 232789.0    229073.0
#     5   3s.3p2                  4       P 2.5 242387.0    238615.0
#     6   3s.3p2                  2       D 1.5 299242.0    298460.0
#     7   3s.3p2                  2       D 2.5 301469.0    300591.0
#     8   3s.3p2                  2       S 0.5 364693.0    367611.0
#     9   3s.3p2                  2       P 0.5 388510.0    392054.0
#    10   3s.3p2                  2       P 1.5 396512.0    400255.0
#   ...      ...   ...          ...     ... ...      ...         ...
# ...

# %%
t.meta['descriptions']
# Out:
# {'E_obs': 'observed energy',
#  'E_th': 'theoretical energy',
#  'J': 'total angular momentum',
#  'L_label': 'orbital angular momentum',
#  'config': 'configuration',
#  'label': 'level label',
#  'level': 'level index',
#  'multiplicity': 'multiplicity, 2s+1'}

# %%
t2 = fiasco.io.Parser('al_6.psplups').parse()

# %%
t2['delta_energy'].to(u.eV)
# Out:
# <Quantity [ 0.33878176, 0.47470263, 0.13601611] eV>

# %%
type(t)
# Out:
# astropy.table.table.QTable

# %%
t['E_obs']
# Out:
# <Quantity [  0.00000000e+00,  1.88520000e+04,  2.25114000e+05,
#              2.32789000e+05,  2.42387000e+05,  2.99242000e+05,
#              3.01469000e+05,  3.64693000e+05,  3.88510000e+05,
#              3.96512000e+05,  4.73223000e+05,  4.75202000e+05,
#              5.76383000e+05,  5.80233000e+05,  5.89002000e+05,
#             -1.00000000e+00,  6.45988000e+05,  6.42179000e+05,
#              6.45409000e+05,  6.51946000e+05,  6.60263000e+05,
#              6.90304000e+05,  6.92662000e+05,  6.94168000e+05,
#              7.03393000e+05,  7.03750000e+05,  7.04209000e+05,
#              7.04114000e+05,  7.17195000e+05,  7.17861000e+05,
#              7.44965000e+05,  7.59814000e+05,  8.07113000e+05,
#              8.15125000e+05,  8.17593000e+05,  8.20601000e+05,
#              8.39492000e+05,  8.40775000e+05,  8.43656000e+05,
#              8.44477000e+05, -1.00000000e+00, -1.00000000e+00,
#             -1.00000000e+00,  9.70948000e+05,  9.77283000e+05,
# ...

# %%
print(t2)
# Out:
# lower_level upper_level bt_type  gf delta_energy  bt_c    bt_rate [9]
#                                          Ry
# ----------- ----------- ------- --- ------------ ----- -----------------
#           1           2       2 0.0       0.0249  61.0        0.0 .. nan
#           1           3       2 0.0      0.03489  32.5        0.0 .. nan
#           2           3       2 0.0     0.009997 186.0 -1e-12 .. 1.7e-10

# %%
type(fiasco.io.Parser('al_6.psplups'))
# Out:
# fiasco.io.sources.ion_sources.PsplupsParser

# %%
import fiasco;import astropy.units as u

# %%
t = np.logspace(4,8,100)*u.K

# %%
ion = fiasco.Ion('Fe 16', temperature=t)

# %%
print(ion._elvlc.footer)
# Out:
# Observed energies: Kramida, A., Ralchenko, Yu., Reader, J., and NIST ASD Team (2012).
# NIST Atomic Spectra Database (ver. 5.0), [Online]. Available: http://physics.nist.gov/
# Theoretical energies:
# outer shell: Liang, G. Y., Whiteford, A. D., & Badnell, N. R. 2009, A&A, 500, 1263
# doi = {10.1051/0004-6361/200911866}
# adsurl = {http://adsabs.harvard.edu/abs/2009A%26A...500.1263L}
# inner shell: Liang, G. Y., Whiteford, A. D., & Badnell, N. R. 2009, Journal of Physics B
# Atomic Molecular Physics, 42, 225002
# doi = {10.1088/0953-4075/42/22/225002}
# adsurl = {http://adsabs.harvard.edu/abs/2009JPhB...42v5002L}
# Produced for the CHIANTI database v.8 by Giulio Del Zanna  Nov 2013

# %%
fiasco.Ion('Fe +15', t), fiasco.Ion('iron 16', t);

# %%
ion.element_name
# Out:
# 'iron'

# %%
ion.atomic_number
# Out:
# 26

# %%
ion.charge_state
# Out:
# 15

# %%
ion.ionization_stage
# Out:
# 16

# %%
ion
# Out:
# CHIANTI Database Ion
# ---------------------
# Name: Fe 16
# Element: iron (26)
# Charge: +15
# Number of Levels: 161
# Number of Transitions: 2815
#
# Temperature range: [0.01 MK, 100.0 MK]
#
# HDF5 Database: /Users/willbarnes/.fiasco/chianti_dbase.h5
# Using Datasets:
#   ioneq: chianti
#   abundance: sun_photospheric_1998_grevesse
#   ip: chianti

# %%
ion.element_name, ion.atomic_symbol, ion.atomic_number
# Out:
# ('iron', 'Fe', 26)

# %%
(ion.ion_name, ion.ionization_stage, ion.charge_state)
# Out:
# ('Fe 16', 16, 15)

# %%
class Foo():
    pass
    def __repr__(self):
        return 'foo!'

# %%
Foo()
# Out:
# foo!

# %%
f

# %%
ion.abundance
# Out:
# <Quantity 3.1622776601683795e-05>

# %%
class Foo():
    _list = [1,2,3]
    def __getitem__(self,key):
        return self._list[key]

# %%
Foo()[1]
# Out:
# 2

# %%
fiasco.Ion('H 10',t)
# Out:
# CHIANTI Database Ion
# ---------------------
# Name: H 10
# Element: hydrogen (1)
# Charge: +9
# Number of Levels: 0
# Number of Transitions: 0
#
# Temperature range: [0.01 MK, 100.0 MK]
#
# HDF5 Database: /Users/willbarnes/.fiasco/chianti_dbase.h5
# Using Datasets:
#   ioneq: chianti
#   abundance: sun_photospheric_1998_grevesse
#   ip: chianti

# %%
d = fiasco.DataIndexer('/Users/willbarnes/.fiasco/chianti_dbase.h5','/h')

# %%
d
# Out:
# /h
#
# Fields
# ------
# abundance  --
# continuum  --
# h_1  --
# h_2  --
#
# Footer
# ------

# %%
type(d)
# Out:
# fiasco.datalayer.DataIndexerLocal

# %%
'h_1' in d
# Out:
# True

# %%
type(d['h_1'])
# Out:
# fiasco.datalayer.DataIndexerLocal

# %%
print(d['h_1/elvlc/E_obs'])
# Out:
# [     0.     82258.956  82258.921  82259.287  97492.224  97492.213
#   97492.321  97492.321  97492.357 102823.855 102823.851 102823.896
#  102823.896 102823.911 102823.911 102823.919 105291.633 105291.631
#  105291.654 105291.654 105291.662 105291.662 105291.666 105291.666
#  105291.668] 1 / cm
